# %% [markdown]
# # Predicting Shelter Animal Outcomes
#
# The goal of this project is to predict the outcome of shelter animals from the [Austin Animal Center](http://www.austintexas.gov/department/animal-services). This is a [past Kaggle competition](https://www.kaggle.com/c/shelter-animal-outcomes) with shelter data from October 1st, 2013 to March, 2016.
#
# There are 5 possible outcomes: Adoption, Transfer, Euthanasia, Return to owner and Died. Thus this is a multiclass classification problem. I will use `Logistic Regression` and `Random Forest` classification algorithms. First let's take a look at the data.

# %%
# import modules/libraries to be used
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import KFold, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
import scipy.stats as stats

# data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv")
print(data.shape)
print(data.dtypes)
# Out:
# (47803, 37)
# animal_id_outcome              object
# dob_year                        int64
# dob_month                       int64
# age_upon_intake                object
# animal_type                    object
# breed                          object
# color                          object
# intake_condition               object
# intake_type                    object
# sex_upon_intake                object
# count                           int64
# age_upon_intake_(days)          int64
# age_upon_intake_(years)       float64
# age_upon_intake_age_group      object
# intake_datetime                object
# intake_month                    int64
# intake_year                     int64
# intake_monthyear               object
# intake_weekday                 object
# intake_hour                     int64
# intake_number                 float64
# time_in_shelter                object
# time_in_shelter_days          float64
# age_upon_outcome               object
# date_of_birth                  object
# sex_upon_outcome               object
# age_upon_outcome_(days)         int64
# age_upon_outcome_(years)      float64
# age_upon_outcome_age_group     object
# outcome_datetime               object
# outcome_month                   int64
# outcome_year                    int64
# outcome_monthyear              object
# outcome_weekday                object
# outcome_hour                    int64
# outcome_number                float64
# outcome_type                   object
# dtype: object

# %%
data.head()
# Out:
#   animal_id_outcome  dob_year  dob_month age_upon_intake animal_type  \
# 0           A006100      2007          7        10 years         Dog
# 1           A006100      2007          7         7 years         Dog
# 2           A006100      2007          7         6 years         Dog
# 3           A047759      2004          4        10 years         Dog
# 4           A134067      1997         10        16 years         Dog
#
#                   breed         color intake_condition      intake_type  \
# 0  Spinone Italiano Mix  Yellow/White           Normal            Stray
# 1  Spinone Italiano Mix  Yellow/White           Normal    Public Assist
# 2  Spinone Italiano Mix  Yellow/White           Normal    Public Assist
# 3             Dachshund      Tricolor           Normal  Owner Surrender
# 4     Shetland Sheepdog   Brown/White          Injured    Public Assist
#
#   sex_upon_intake  ...  age_upon_outcome_(years)  age_upon_outcome_age_group  \
# 0   Neutered Male  ...                      10.0                 (7.5, 10.0]
# 1   Neutered Male  ...                       7.0                  (5.0, 7.5]
# 2   Neutered Male  ...                       6.0                  (5.0, 7.5]
# 3   Neutered Male  ...                      10.0                 (7.5, 10.0]
# 4   Neutered Male  ...                      16.0                (15.0, 17.5]
#
#       outcome_datetime outcome_month outcome_year  outcome_monthyear  \
# 0  2017-12-07 14:07:00            12         2017            2017-12
# 1  2014-12-20 16:35:00            12         2014            2014-12
# 2                  NaN             3         2014            2014-03
# 3  2014-04-07 15:12:00             4         2014            2014-04
# 4  2013-11-16 11:54:00            11         2013            2013-11
#
#    outcome_weekday outcome_hour outcome_number     outcome_type
# 0         Thursday            0            1.0  Return to Owner
# 1         Saturday           16            2.0  Return to Owner
# 2         Saturday           17            3.0  Return to Owner
# 3           Monday           15            1.0          Missing
# 4         Saturday           11            1.0  Return to Owner
#
# [5 rows x 37 columns]

# %%
data.outcome_type.value_counts()
# Out:
# Adoption           12967
# Transfer           10345
# Return to Owner     9718
# Euthanasia          4144
# Died                2829
# Missing             2599
# Relocate            2573
# Rto-Adopt           2450
# Disposal             178
# Name: outcome_type, dtype: int64

# %%
data.isnull().sum()
# Out:
# animal_id_outcome                0
# dob_year                         0
# dob_month                        0
# age_upon_intake                  0
# animal_type                      0
# breed                            0
# color                            0
# intake_condition                 0
# intake_type                      0
# sex_upon_intake                  1
# count                            0
# age_upon_intake_(days)           0
# age_upon_intake_(years)          0
# age_upon_intake_age_group        0
# intake_datetime                  0
# intake_month                     0
# intake_year                      0
# intake_monthyear                 0
# intake_weekday                   0
# intake_hour                      0
# intake_number                    0
# time_in_shelter                  0
# time_in_shelter_days             0
# age_upon_outcome                 0
# date_of_birth                    0
# sex_upon_outcome                 1
# age_upon_outcome_(days)          0
# age_upon_outcome_(years)         0
# age_upon_outcome_age_group       0
# outcome_datetime              9619
# outcome_month                    0
# outcome_year                     0
# outcome_monthyear                0
# outcome_weekday                  0
# outcome_hour                     0
# outcome_number                   0
# outcome_type                     0
# dtype: int64

# %% [markdown]
# ## 1. Data Transformation and Exploration
# Before I start predicting outcomes, I need to format and transform features to be suitable for analyses. I would also like to visualize their individual relationship to the outcomes.

# %% [markdown]
# ### a. Animal Type

# %%
AnimalTypeGroup = data.groupby('animal_type')
print(AnimalTypeGroup.animal_type.value_counts())
AnimalTypeGroup.outcome_type.value_counts()
# Out:
# animal_type  animal_type
# Bird         Bird             172
# Cat          Cat            16951
# Dog          Dog            28222
# Other        Other           2458
# Name: animal_type, dtype: int64
# animal_type  outcome_type
# Bird         Adoption             49
#              Transfer             34
#              Euthanasia           32
#              Disposal             17
#              Died                 13
#              Relocate             11
#              Missing               7
#              Rto-Adopt             7
#              Return to Owner       2
# Cat          Transfer           5777
#              Adoption           4679
#              Died               1279
#              Relocate           1136
#              Missing            1124
#              Rto-Adopt          1049
#              Euthanasia         1009
#              Return to Owner     896
#              Disposal              2
# Dog          Return to Owner    8802
#              Adoption           8211
#              Transfer           4276
#              Died               1443
#              Missing            1433
#              Relocate           1386
#              Rto-Adopt          1363
#              Euthanasia         1305
#              Disposal              3
# Other        Euthanasia         1798
#              Transfer            258
#              Disposal            156
#              Died                 94
#              Relocate             40
#              Missing              35
#              Rto-Adopt            31
#              Adoption             28
#              Return to Owner      18
# Name: outcome_type, dtype: int64

# %%
AnimalTypeGraph = data[['animal_type','outcome_type']].groupby(['outcome_type','animal_type']).size().unstack()
AnimalTypeGraph.plot(kind='bar',color=['r','c'])

# %% [markdown]
# Dogs are frequently adopted and returned to owner. Cats are most frequently transferred and not returned to owner. This indicates more cats are probably strays and not microchipped. There is unequal amount of cat and dog data so we can't make any assumptions based on empirical differences in bar height.

# %% [markdown]
# ### b. DateTime

# %%
#format Datetime
data['intake_datetime'] = pd.to_datetime(data['intake_datetime'])

# %%
data['intake_hour'] = data.intake_datetime.dt.hour

# %%
# Outcomes by Hour
hourGroup=data.intake_hour.groupby(data.outcome_type)
plt.subplots(5, 1, figsize=(15, 20), sharex=True)
plt.subplots_adjust( hspace=0.5)
colors = list('rgbcmyk')
for i, (f, g) in enumerate(hourGroup):
    plt.subplot(5,1,i+1)
    plt.title(f)
    g.groupby(data.intake_hour).count().plot(kind="line", color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1f4e4a96f9e3> in <module>
#       5 colors = list('rgbcmyk')
#       6 for i, (f, g) in enumerate(hourGroup):
# ----> 7     plt.subplot(5,1,i+1)
#       8     plt.title(f)
#       9     g.groupby(data.intake_hour).count().plot(kind="line", color=colors[i])
#
# C:\Program Files (x86)\New folder\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# C:\Program Files (x86)\New folder\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# C:\Program Files (x86)\New folder\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      58                     raise ValueError(
#      59                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 60                         ).format(maxn=rows*cols, num=num))
#      61                 self._subplotspec = GridSpec(
#      62                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 5, not 6

# %% [markdown]
# Adoptions mostly occur in the nighttime, after work hours. There is a large spike in transfers occuring in the early morning and then a gradual trend in the late afternoon. The other outcomes don't seem to reveal any significant trends.

# %%
data['DoW'] = data.intake_datetime.dt.dayofweek

# %%
data.head()
# Out:
#   animal_id_outcome  dob_year  dob_month age_upon_intake animal_type  \
# 0           A006100      2007          7        10 years         Dog
# 1           A006100      2007          7         7 years         Dog
# 2           A006100      2007          7         6 years         Dog
# 3           A047759      2004          4        10 years         Dog
# 4           A134067      1997         10        16 years         Dog
#
#                   breed         color intake_condition      intake_type  \
# 0  Spinone Italiano Mix  Yellow/White           Normal            Stray
# 1  Spinone Italiano Mix  Yellow/White           Normal    Public Assist
# 2  Spinone Italiano Mix  Yellow/White           Normal    Public Assist
# 3             Dachshund      Tricolor           Normal  Owner Surrender
# 4     Shetland Sheepdog   Brown/White          Injured    Public Assist
#
#   sex_upon_intake  ...  age_upon_outcome_age_group     outcome_datetime  \
# 0   Neutered Male  ...                 (7.5, 10.0]  2017-12-07 14:07:00
# 1   Neutered Male  ...                  (5.0, 7.5]  2014-12-20 16:35:00
# 2   Neutered Male  ...                  (5.0, 7.5]                  NaN
# 3   Neutered Male  ...                 (7.5, 10.0]  2014-04-07 15:12:00
# 4   Neutered Male  ...                (15.0, 17.5]  2013-11-16 11:54:00
#
#    outcome_month outcome_year outcome_monthyear  outcome_weekday  \
# 0             12         2017           2017-12         Thursday
# 1             12         2014           2014-12         Saturday
# 2              3         2014           2014-03         Saturday
# 3              4         2014           2014-04           Monday
# 4             11         2013           2013-11         Saturday
#
#    outcome_hour outcome_number     outcome_type  DoW
# 0             0            1.0  Return to Owner    3
# 1            16            2.0  Return to Owner    4
# 2            17            3.0  Return to Owner    4
# 3            15            1.0          Missing    2
# 4            11            1.0  Return to Owner    5
#
# [5 rows x 38 columns]

# %%
# Outcomes per Week
weekGroup=data.DoW.groupby(data.outcome_type)
plt.subplots(5, 1, figsize=(15, 20), sharex=True)
plt.subplots_adjust( hspace=0.5)
colors = list('rgbcmyk')
for i, (f, g) in enumerate(weekGroup):
    plt.subplot(5,1,i+1)
    plt.title(f)
    g.groupby(data.DoW).count().plot(kind="line", color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-913b3139027b> in <module>
#       5 colors = list('rgbcmyk')
#       6 for i, (f, g) in enumerate(weekGroup):
# ----> 7     plt.subplot(5,1,i+1)
#       8     plt.title(f)
#       9     g.groupby(data.DoW).count().plot(kind="line", color=colors[i])
#
# C:\Program Files (x86)\New folder\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# C:\Program Files (x86)\New folder\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# C:\Program Files (x86)\New folder\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      58                     raise ValueError(
#      59                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 60                         ).format(maxn=rows*cols, num=num))
#      61                 self._subplotspec = GridSpec(
#      62                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 5, not 6

# %% [markdown]
# The beginning of the week starts with Monday, represented by 0.
#
# Transfers and Return to owner seems to happen most often at the beginning of the week, whereas Adoptions mostly happen on the weekends. Euthanasia must be performed by certified technician/veterinarian who mostly come in on weekdays.

# %%
data['Month'] = data.DateTime.dt.month

# %%
# Outcomes by Month
monthGroup=data.Month.groupby(data.OutcomeType)
plt.subplots(5, 1, figsize=(15, 20), sharex=True)
plt.subplots_adjust(hspace=0.5)
colors = list('rgbcmyk')
for i, (f, g) in enumerate(monthGroup):
    plt.subplot(5,1,i+1)
    plt.title(f)
    g.groupby(data.Month).count().plot(kind="line", color=colors[i])

# %% [markdown]
# ### c. Age

# %%
# Convert Age into numerical format
# create list of age in days
dataAge = data.AgeuponOutcome.tolist()
AgeinDays = []
for i in dataAge:
    try:
        num = (i.split()[0])
        letter = (i.split()[1][0])
        if(letter == 'y'):
            days = int(num)*365
        elif(letter == 'm'):
            days = int(num)*30
        elif(letter == 'w'):
            days = int(num)*7
        else:
            days = int(num)
        AgeinDays.append(days)
    except:
        AgeinDays.append(np.nan)

# %%
# append numerical age column to data set
data['AgeinDays'] = AgeinDays

# %%
# fill missing value with median age
age_median =  data.AgeinDays.median()
data.AgeinDays.fillna(age_median, inplace=True)
print(data.AgeinDays.isnull().sum())

# %%
# Break age into baby(0-6 months), puppy(6-18 months), adult (18 - inf)
data['Lifestage'] = pd.cut(data.AgeinDays,[-1,180,365,np.inf])
data.Lifestage.value_counts()

# %%
sns.countplot(data = data, x='Lifestage', hue='OutcomeType')

# %%
del data['AgeuponOutcome']
data.head()

# %% [markdown]
# ### d. Breed Data

# %%
data.Breed

# %%
# create column to identify mixed breeds
mixMask = ['Mix' in breed for breed in data.Breed.tolist()]
data['MixedBreed'] = mixMask
data.MixedBreed = data.MixedBreed.astype(int)

# %%
# Simplify breed data into individual breed components
data[['FirstBreed',
      'SecondBreed',
      'ThirdBreed']] = data.Breed.str.split("/", expand=True)

# %%
BreedData = data.FirstBreed.tolist()
FirstBreedList = []
for breed in BreedData:
    if "Mix" in breed: 
        breed = breed[0:-4]
    FirstBreedList.append(breed)

# %%
data['FirstBreed'] = FirstBreedList

# %%
# Number of breed levels is greatly reduced
print(data.Breed.nunique())
data.FirstBreed.nunique()

# %% [markdown]
# ### e. Color

# %%
data.Color

# %%
# Simplify color data into individual components
data[['FirstColor','SecondColor']] = data.Color.str.split("/", expand=True)
print(data.FirstColor.nunique())
data.FirstColor.value_counts().sum()

# %% [markdown]
# ### f. Sex and Sterilization

# %% [markdown]
# Sex and Sterilization are two distinct features so it makes more sense to separate it into two columns instead of 4 compound dummy columns.

# %%
# Fill missing values 
data.SexuponOutcome.fillna("Unknown", inplace=True)
data.SexuponOutcome.value_counts()

# %%
# Separate SexuponOutcome column into Sex and Neutered/Spayed 
# Female = 1 and Intact = 1
sexMask = ['Female' in sex for sex in data.SexuponOutcome.tolist()]
sterileMask = ['Intact' in fix for fix in data.SexuponOutcome.tolist()]

# %%
data['Sex'] = sexMask
data['Sterile'] = sterileMask
data.Sex = data.Sex.astype(int)
data.Sterile = data.Sterile.astype(int)

# %%
# There is almost equal amount of male and female data
data.Sex.value_counts()

# %%
# Sterilizaion data is highly unbalanced: most animals are sterilized, almost 74%
data.Sterile.value_counts()

# %%
del data['SexuponOutcome']
data.head()

# %%
sns.countplot(data = data, x='Sterile', hue='OutcomeType')

# %% [markdown]
# Sterilization likely leads to more adoptions because:
#    1. Owners won't have to deal with cost and time associated with neutering/spaying their animal.
#    2. Males are less aggressive and territorial, and females won't go into heat or draw unwanted male advances
#    3. Caring for an unexpected litter is costly

# %%
sns.countplot(data = data, x='Sex', hue='OutcomeType')

# %% [markdown]
# Sex doesn't seem to have a large effect on outcomes.

# %% [markdown]
# ## Logistic Regression
# First I will use a logistic regression model to

# %%
data.columns.tolist()

# %%
# Generate features and target
feature_cols = [
 'AnimalType',
 'Hour',
 'DoW',
 'Month',
 'AgeinDays',
 'Lifestage',
 'MixedBreed',
 'FirstBreed',
 'FirstColor',
 'Sex',
 'Sterile'
 ]
le = LabelEncoder()
encoded_X = data[feature_cols].apply(le.fit_transform)
X = encoded_X
y = le.fit_transform(data.OutcomeType)

# %%
# Compute Logistic Regression to Predict Outcome
logreg = LogisticRegression(random_state=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.3)
logreg.fit(X_train,y_train)
OutcomePredLog = logreg.predict(X_test)
print('Model Accuracy:',metrics.accuracy_score(y_test, OutcomePredLog))

# %%
cross_val_scores_log = cross_val_score(logreg,X,y,cv=10,scoring='accuracy')
print("Mean cross validation accuracy:",np.mean(cross_val_scores_log))
print("Std of cross validation accuracy:",np.std(cross_val_scores_log))

# %%
list(zip(feature_cols, logreg.coef_[0]))

# %% [markdown]
# ## Random Forest

# %%
# Generate Random Forest with 100 trees using train_test_split method
rf100 = RandomForestClassifier(n_estimators=100,random_state=1)

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.3)
rf100.fit(X_train, y_train)
y_pred_rf_100 = rf100.predict(X_test)

print("Random Forest Train-Test accuracy:",metrics.accuracy_score(y_test,y_pred_rf_100))

# %%
# random forest with cross validation method
cross_val_scores_100 = cross_val_score(rf100,X,y,cv=10,scoring='accuracy')
print("Mean cv-accuracy:",np.mean(cross_val_scores_100))
print("Std of cv-accuracy:",np.std(cross_val_scores_100))

# %%
pd.DataFrame({'feature':feature_cols, 
              'importance':rf100.feature_importances_}).sort_values(by='importance', ascending=False)

# %% [markdown]
# ### Grid Search on Logistic Regression and Random Forest

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf_for_grid = RandomForestClassifier(random_state=1, n_jobs=-1)
estimator_range = range(10,101,10)
feature_range = range(1,len(feature_cols)+1)
param_grid = dict(n_estimators = estimator_range, 
                  max_features = feature_range)
RFgrid = GridSearchCV(rf_for_grid, param_grid, cv=10, scoring='accuracy')
RFgrid.fit(X, y)

# %%
rf_for_grid.get_params()

# %%
RFgrid.best_estimator_

# %%
RFgrid.best_score_

# %%
RFgrid.best_params_

# %%
RFgrid.grid_scores_

# %%
rf_best = RandomForestClassifier(n_estimators=70, max_features=5, max_depth = 12, random_state=1)

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.3)
rf_best.fit(X_train, y_train)
y_pred_prob_rf_best = rf_best.predict_proba(X_test)
y_pred_rf_best = rf_best.predict(X_test)

print("Mean Accuracy for depth 12:", cross_val_score(rf_best, X, y, scoring='accuracy').mean())

# %%
# compute feature importances
pd.DataFrame({'feature':feature_cols, 
              'importance':rf_best.feature_importances_}).sort_values(by='importance', ascending=False)

# %% [markdown]
# The animal's age and sterility are important to predicting outcomes in the random forest model.

# %%
log_for_grid = LogisticRegression()
param_grid2 = {"penalty":['l1','l2'], 'C':[0.1,1,10,100]}
LogGrid = GridSearchCV(log_for_grid, param_grid2, cv=10, scoring='accuracy')
LogGrid.fit(X, y)

# %%
log_for_grid.get_params()

# %%
LogGrid.grid_scores_

# %%
LogGrid.best_score_

# %%
LogGrid.best_params_

# %%
best_log = LogisticRegression(C=0.1, penalty='l1')
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.3)
best_log.fit(X_train, y_train)
y_pred_prob_log_best = best_log.predict_proba(X_test)

# %%
# beta values of best Logistic Regression Model
betas = best_log.fit(X,y).coef_[0]
best_betas = pd.DataFrame(list(zip(feature_cols,betas)),columns=["features","betas"])
best_betas.sort_values("betas",ascending=False,inplace=True)
best_betas

# %% [markdown]
# Features significant in predicting outcomes for the logistic regression model include the animal's age and sterility. This mirrors the results we saw in the random forest model.

# %% [markdown]
# ##  Model Evaluation

# %%
# test against null accuracy
from sklearn.dummy import DummyClassifier
dumb_model = DummyClassifier(strategy='most_frequent')
cross_val_score(dumb_model,X,y,cv=10).mean()

# %%
# Confusion Matrix for Outcomes
cm_rf = metrics.confusion_matrix(y_test, y_pred_rf_best, 
                                 labels= [4,3,2,1,0])
cm_rf

# %%
# calculate AUC for logreg and random forest
print("LogReg model AUC: ",metrics.roc_auc_score(y_test, y_pred_prob_log_best[:,1]))
print("RF model AUC: ",metrics.roc_auc_score(y_test, y_pred_prob_rf_best[:,1]))

# %% [markdown]
# ## For the future....
#
# - Perform Multiple Correspondence Analysis (MCA), PCA for categorical data
# - Figure out the confusion matrix and ROC curve/AUC score for each outcome
#
# ![thanksdawg.png](attachment:thanksdawg.png)
